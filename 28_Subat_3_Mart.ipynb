# %%
grocer1 = {'fruit': 'apple', 'drink': 'water'}            #   bütün degerler tirnak icerisine alinmalidir. Süslü parantez icine alinir veya dict sarmali alinir
grocer2 = dict (fruit = 'apple', drink = 'water')         #   sarmal icine alinca key tirnak icinde yazilmaz ve esittir "=" kullanilir
print(grocer1)
print(grocer2)
# Out:
# {'fruit': 'apple', 'drink': 'water'}
# {'fruit': 'apple', 'drink': 'water'}

# %%
ad = [ 'one', 'two', 'three', 'four', 'five']
no = [1, 2, 3, 4, 5]
szlk = dict(zip(ad, no))                          #   zip sözlük  tarzi bir yapi icin kullanilabilir
liste = list(zip(ad, no))
print(szlk)
print(liste)
print(zip(ad, no))                                #   mutlaka bir koleksiyon tipine dönüstürmek istiyor.
# Out:
# {'one': 1, 'two': 2, 'three': 3, 'four': 4, 'five': 5}
# [('one', 1), ('two', 2), ('three', 3), ('four', 4), ('five', 5)]
# ...

# %%
sozluk = {'one':1, 'two': 2, 'three': 3}
print(sozluk)
# Out:
# {'one': 1, 'two': 2, 'three': 3}

# %%
state = {'city': 'Berlin',              #   aralarda virgül olmasi zorunlu
         'land': 'Deutschland',
         'strase': 'Richard',           #   sözlük icinde birden fazla ayni eleman olamaz. sadece son degeri verir
         'strase': 'delitzscher'
        }
state['no'] = 21                        #   eleman eklemesi yaptik
state['city'] = 'Halle'                 #   sozluk icinden degistirme yaptik
print(state)
# Out:
# {'city': 'Halle', 'land': 'Deutschland', 'strase': 'delitzscher', 'no': 21}

# %%
family = {'name1': 'ahmet',
          'name2': 'ayse',
          'name3': 'veli'
         }
family2 = dict(name1 = 'ahmet', name2 = 'ayse', name3 = 'veli')
family['name4'] = 'Cemil' 
family2['name4'] = 'Cemil'                                            #   dict sarmali icine de ayni yöntem ile ekleme yapilabilir
print(family)
print(family2)
# Out:
# {'name1': 'ahmet', 'name2': 'ayse', 'name3': 'veli', 'name4': 'Cemil'}
# {'name1': 'ahmet', 'name2': 'ayse', 'name3': 'veli', 'name4': 'Cemil'}

# %%
t = (5, 7, 9)
day = ('Montag', 'Dienstag', 'Mittwoch', 'Donerstag', 'Freitag', 'Samstag', 'Sontag') 
print(list(enumerate(t, start=1)))              #   verilerin sirasini listeliyor. start ile baslangic degeri verdik
print(tuple(enumerate(day)))                    #   baslangic degeri vermezsek "0" dan baslar. list yada tuple sarmalina alinmasi gerekiyor.
                                                #   "enumerate" sadece sirali veri yapilarinda kullanilir (list ve tuple gibi)
# Out:
# [(1, 5), (2, 7), (3, 9)]
# ((0, 'Montag'), (1, 'Dienstag'), (2, 'Mittwoch'), (3, 'Donerstag'), (4, 'Freitag'), (5, 'Samstag'), (6, 'Sontag'))

# %%
szlk = {'animal': 'dog',
        'planet': 'neptun',
        'number': 40,
        'pi': 3.14,
        'good': True
       }
print(*szlk.items())              #   anahtar kelime ve degerleri beraber yazdirdik 
print(*szlk.keys())               #   sadece anahtar kelimeleri yazdirdik
print(szlk.values())              #   sadece degerleri yazdiriyor   "*" koyarak bastaki tanimdan ve tirnaktan kurtaririz
print(list(szlk.values()))        #   liste sarmali ile de basindaki tanimdan kurtarabiliriz
print(tuple(szlk.values()))
# Out:
# ('animal', 'dog') ('planet', 'neptun') ('number', 40) ('pi', 3.14) ('good', True)
# animal planet number pi good
# dict_values(['dog', 'neptun', 40, 3.14, True])
# ['dog', 'neptun', 40, 3.14, True]
# ('dog', 'neptun', 40, 3.14, True)

# %%
szlk = {'animal': 'dog',
        'planet': 'neptun',
        'number': 40,
        'pi': 3.14,
        'good': True
       }
szlk.update({'good': False})              #   veri degerini update ile degistirdik
print(szlk)
# Out:
# {'animal': 'dog', 'planet': 'neptun', 'number': 40, 'pi': 3.14, 'good': False}

# %%
d1 = {1: 'bir', 2: 'iki', 3:'üc'}
d2 = {1: 'vier', 2: 'fünf', 3: 'sechs'}
d1.update(d2)                             #   d1 icine update ile d2 listesini degistirdik
print(d1)
# Out:
# {1: 'vier', 2: 'fünf', 3: 'sechs'}

# %%
szlk = {'animal': 'dog',
        'planet': 'neptun',
        'number': 40,
        'pi': 3.14,
        'good': True
       }  
del szlk['planet']                  #   sözlük icinden istedigimiz key ve degeri silmek icin kullanilir. icine tek deger aliyor
print(szlk)
szlk.clear()                        #   "clear" ile sözlük icini tamamen silebiliriz
print(szlk)
# Out:
# {'animal': 'dog', 'number': 40, 'pi': 3.14, 'good': True}
# {}

# %%
family = {'name1': 'ahmet',
          'name2': 'ayse',
          'name3': 'veli',
          'name4': 'Cemil',
          'name5': 'Murat'
         }
family = list(family.items())                 #   list döngüsü icine alarak dilimledik
del family[0:2]                               #   birden fazla silme yapmak icin köseli parantez ile sinirlari belirledik
print(dict(family))                           #   tekrar "dict" formatina dönüstürerek yazdirdik
# Out:
# {'name3': 'veli', 'name4': 'Cemil', 'name5': 'Murat'}

# %%
family = {'name1': 'ahmet',
          'name2': 'ayse',
          'name3': 'veli',
          'name4': 'Cemil',
          'name5': 'Murat'
         }
print('ayse' in family.values())          #   sadece degerlerin icinde arama yaptirdik
print('name3' in family)                  #   normalde sadece "key" ler arasinda arama yapiyor
print('name6' not in family)              #   burada icinde degil mi diye sorgulama yapiyoruz
# Out:
# True
# True
# True

# %%
form = {'personal':{                                                           
                   'erkek':                                                     
                            {'ali': {'sname': 'Kurt', 'age': 25},               
                             'veli':{'sname': 'Nergiz', 'age': 32},            
                            },                                                  
                   'bayan':
                            {'ayse': {'sname': 'Ulu', 'age': 21},
                             'umran': {'sname': 'Demir', 'age': 19}
                            },
                    },    
       }
print(form['personal']['erkek']['ali']['sname'])                        #   ic ice girerek sadece kisinin soyadini yazdirdik
print(list(form['personal']['erkek']['ali'].items()))                   #   list formatinda listelemek icin kullandik
# Out:
# Kurt
# [('sname', 'Kurt'), ('age', 25)]

# %%
friends = {'friend': {
                'friend1': {'first': 'Sue', 'last': 'Bold'},
                'friend2': {'fisrt': 'Steve', 'last': 'Job'},
                'friend3': {'first': 'Murat', 'last': 'Terzi'},  
                     },  
           'family': {
                'famil1' : {'first': 'Cemil', 'last': 'Can'},
                'family2': {'first': 'Ahmet', 'last': 'Ertürk'},
                'family3': {'first': 'Ufuk', 'last': 'Gökkaya'},
                      },
          }
print(friends)
# Out:
# {'friend': {'friend1': {'first': 'Sue', 'last': 'Bold'}, 'friend2': {'fisrt': 'Steve', 'last': 'Job'}, 'friend3': {'first': 'Murat', 'last': 'Terzi'}}, 'family': {'famil1': {'first': 'Cemil', 'last': 'Can'}, 'family2': {'first': 'Ahmet', 'last': 'Ertürk'}, 'family3': {'first': 'Ufuk', 'last': 'Gökkaya'}}}

# %%
# girilen rakamin karsiligini veren program. girilen sayi yoksa sözlükte yok desin.
rakam = int(input('1 - 9 arasi sayi gir..: '))
my_dict = {1: 'bir', 2: 'iki', 3: 'üc', 4: 'dört', 5: 'bes', 6: 'alti', 7: 'yedi', 8: 'sekiz', 9: 'dokuz'}
print(my_dict.get(rakam, 'sözlükte yok'))             #   key degeri varsa karsiligini verir yoksa istedigimiz yaziyi yazar. yazi yoksa None degeri verir
                                                      #   get(key(True), 'sözlükte yok' (False)) mantigi ile calisir
# Out:
# 1 - 9 arasi sayi gir..: 4
# dört

# %% [markdown]
# # **3 Mart Ders Notlari**

# %%
a = dict(one = 1, two = 2, three = 3)                 #   atama gibi yaparak daha sonra dict sarmalina alinabilir
b = {'one': 1, 'two': 2, 'three': 3}
c = dict(zip(['one', 'two', 'three'], [1, 2, 3]))
d = list(b.items())                                   #   tüm degerleri almak icin items ile kullanilmali
print(a) 
print(b) 
print(c) 
print(d)
# Out:
# {'one': 1, 'two': 2, 'three': 3}
# {'one': 1, 'two': 2, 'three': 3}
# {'one': 1, 'two': 2, 'three': 3}
# [('one', 1), ('two', 2), ('three', 3)]

# %%
family = {'name1': 'ahmet',
          'name2': 'ayse',
          'name3': 'veli',
          'name4': 'Cemil',
          'name5': 'Murat'
         }
family.update({'name4': 'Ali', 'name5': 'hakan'})           #   ayni key varsa degistirir yoksa sonuna ekleme yapar.
del family['name1']
print(family.pop('name6', 'Sözlükte yoktur'))               #   istedigimiz degeri silme islemi yapar. olmayan deger girilirsa bilgi verir.
print('silinen..:', family.popitem())                       #   son eklenen degeri veya son degeri siler
print('veli' in family.values())                            #   degerler arasinda arama yaparken kullanilir
print('veli' in family['name3'])                        
print(family)
if 'veli' in family.values():
    print(family['name3'])
# Out:
# Sözlükte yoktur
# silinen..: ('name5', 'hakan')
# True
# True
# {'name2': 'ayse', 'name3': 'veli', 'name4': 'Ali'}
# veli

# %%
friends = {'friend': {
                'friend1': {'first': 'Sue', 'last': 'Bold'},
                'friend2': {'fisrt': 'Steve', 'last': 'Job'},
                'friend3': {'first': 'Murat', 'last': 'Terzi'},  
                     },  
           'family': {
                'famil1' : {'first': 'Cemil', 'last': 'Can'},
                'family2': {'first': 'Ahmet', 'last': 'Ertürk'},
                'family3': {'first': 'Ufuk', 'last': 'Gökkaya'},
                      },
          }
del_f = friends['family']['family3']
del_f2 = friends['family'].popitem()
print(del_f)
print(del_f2)
# Out:
# {'first': 'Ufuk', 'last': 'Gökkaya'}
# ('family3', {'first': 'Ufuk', 'last': 'Gökkaya'})

# %%
d = {'foo': 100, 'bar': 200, 'baz': 300, 'zoo': 400}
sil = int(input('bir deger girin..:'))
k = list(d.keys())
v = list(d.values())
indis = v.index(sil)
d.pop(k[indis])
print(d)
# Out:
# bir deger girin..:100
# {'bar': 200, 'baz': 300, 'zoo': 400}

# %% [markdown]
# ### **Kümeler**

# %%
set1 = {'red', 'blue', 'pink', 'red'}             #   {} parantez ile olusur ve sirasiz bir sekilde yazdirir
set2 = 'red', 'blue', 'pink', 'red'               #   küme icindeki elemanlarin hepsinden birer tane gösterir. tekrarlama olmaz
new = set(set2)                                   #   set sarmalina alinabilir
print(set1)
print(new)
# Out:
# {'blue', 'pink', 'red'}
# {'blue', 'pink', 'red'}

# %%
b_kume = set()                    #   bos küme olusturmak icin "set" sarmalina almak gerekir.
b2_kume = {}                      #   burada bos olsada "dict" olarak algiladi.
print(type(b_kume))
print(type(b2_kume))
# Out:
# <class 'set'>
# <class 'dict'>

# %%
a = set('philadelphia')
b = set('dolphin')                        #   set sarmalina alininca karakterlerin hepsini ayiriyor
c = {'Mehmet', 'ali'}                     #   {} icindekini tek bütün olarak aliyor
print(c, type(c))
print(a)
print(b)
print('a fark b..:', a.difference(b))
print('a fark b..:', a - b)
print('birlesim..:', a.union(b))
print('birlesim..:', a | b)
print('kesisme..:', a.intersection(b))
print('kesisme..:', a & b)
# Out:
# {'ali', 'Mehmet'} <class 'set'>
# {'a', 'd', 'e', 'i', 'h', 'l', 'p'}
# {'n', 'd', 'i', 'h', 'l', 'p', 'o'}
# a fark b..: {'e', 'a'}
# a fark b..: {'e', 'a'}
# birlesim..: {'n', 'a', 'd', 'e', 'i', 'h', 'l', 'p', 'o'}
# birlesim..: {'n', 'a', 'd', 'e', 'i', 'h', 'l', 'p', 'o'}
# kesisme..: {'d', 'i', 'h', 'l', 'p'}
# kesisme..: {'d', 'i', 'h', 'l', 'p'}

# %%
c = {'03.02.2000', '05.02.2020', '05.02.2020'}
d = set('03.02.2000')                                 #   icine tek bir eleman aliyor virgül ile ayrilirsa vermez
f = set(['03.02.2000', '05.02.2020'])                 #   birden fazla deger icin [] yada () icine alinabilir   
e = {(1,2,3,4,5,6,7)}
print(c)
print(d)
print(e)
print(f)
# Out:
# {'05.02.2020', '03.02.2000'}
# {'2', '0', '3', '.'}
# {(1, 2, 3, 4, 5, 6, 7)}
# {'05.02.2020', '03.02.2000'}

# %%
a = set('philadelphia')
b = frozenset(a)              #   icine ekleme yapilamaz
a.add('x')
#b.add('e')
print(b)
print(a)
# Out:
# frozenset({'a', 'h', 'd', 'l', 'e', 'p', 'i'})
# {'a', 'x', 'd', 'e', 'i', 'h', 'l', 'p'}

# %%
a = set('philadelphia')
b = set('dolphin')
print(a)
print(b)
a.remove('h')                   #   istenilen karakteri kaldirmak icin kullanilir. eleman yoksa hata verir
a.pop()                         #   rastgele bir elemani siler. argüman istemiyor
print(a)
b.discard('d')                  #   küme icinden istenilen karakteri siler. Karakter yoksa hicbir sey yapmaz
b.discard('x')                  #   Karakter yoksa hicbir sey yapmaz

print(b)
# Out:
# {'a', 'd', 'e', 'i', 'h', 'l', 'p'}
# {'n', 'd', 'i', 'h', 'l', 'p', 'o'}
# {'d', 'e', 'i', 'l', 'p'}
# {'n', 'i', 'h', 'l', 'p', 'o'}

# %%
a = set('philadelphia')
b = {'p', 'i', 'l'}
print(a)
print(b)
print(b.issubset(a))               #  b kümesi a nin alt kümesi mi diye sorduk
print(a.issuperset(b))             #  a kümesi b kümesini kapsar mi
print(b.issuperset(a))             #  b kümesi a kümesini kapsar mi
# Out:
# {'a', 'd', 'e', 'i', 'h', 'l', 'p'}
# {'p', 'i', 'l'}
# True
# True
# False

# %%
print(dir(set))
dir(set)

# %%
alm_turk = {
    "farben":
        {"schwarz":"siyah", "weiß":"beyaz", "gelb":"sarı", "rot":"kırmızı", "blau":"mavi", "grün":"yeşil", "orange":"turuncu",
         "rosa":"pembe", "grau":"gri", "braun":"kahverengi", "bordeaux":"bordo", "lila":"mor", "türkis":"turkuaz"
               },
    "tage":
        {"montag":"Pazartesi", "dienstag":"Salı", "mittwoch":"Çarşamba", "donerstag":"Perşembe", "freitag":"Cuma", "samstag":"Cumartesi", "sonntag":"Pazar"
               },
    "monate":
    {"januar":"Ocak", "februar":"Şubat", "märz":"Mart", "april":"Nisan", "mai":"Mayıs", "juni":"Haziran", "juli":"Temmuz", "august":"Ağustos",
     "september":"Eylül", "oktober":"Ekim", "november":"Kasım", "dezember":"Aralık"},
}
key = input("Almanca bir renk, gün veya ay adi yaziniz: ")
#alm_turk["monate"][key]
f = alm_turk['farben'].get(key,0)
t = alm_turk['tage'].get(key,0)
m = alm_turk['monate'].get(key,0)
if f != 0:
  print(f)
elif t !=0:
  print(t)
elif m !=0:
  print(m)
else:
  print("sözlükte yoktur")

# %%
def git(linenum):
    global line
    line = linenum

line = 1
while True:
    if line == 1:
        response = input("yes or no? ")
        if response == "yes":
            git(2)
        elif response == "no":
            git(3)
        else:
            git(100)
    elif line == 2:
        print("Thank you for the yes!")
        git(20)
    elif line == 3:
        print("Thank you for the no!")
        git(20)
    elif line == 20:
        break
    elif line == 100:
        print("You're annoying me - answer the question!")
        git(1)
# Out:
# yes or no? yes
# Thank you for the yes!

# %%
def go(yol):
    global line
    line =yol
line = 1
while True:
    if line == 1:
        girdi = input('yes or no..: ')
        if girdi == 'yes':
            git(2)
        elif girdi == 'no':
            git(3)
        else:
            git(1)
    elif line == 2:
        print('Yes komutu girildi...')
        git(10)
    elif line == 3:
        print('No komutu girildi...')
        git(10)
    elif line == 10:
        break
# Out:
# yes or no..: er
# yes or no..: er
# yes or no..: yes
# Yes komutu girildi...

# %%
friends = {'friend': {
                'friend1': {'first': 'Sue', 'last': 'Bold'},
                'friend2': {'fisrt': 'Steve', 'last': 'Job'},
                'friend3': {'first': 'Murat', 'last': 'Terzi'},  
                     },  
           'family': {
                'famil1' : {'first': 'Cemil', 'last': 'Can'},
                'family2': {'first': 'Ahmet', 'last': 'Ertürk'},
                'family3': {'first': 'Ufuk', 'last': 'Gökkaya'},
                      },
          }
for i in friends['friend'].items():
    print(i)
print('abcdefcdghcd'.split('cd'))
# Out:
# ('friend1', {'first': 'Sue', 'last': 'Bold'})
# ('friend2', {'fisrt': 'Steve', 'last': 'Job'})
# ('friend3', {'first': 'Murat', 'last': 'Terzi'})
# ['ab', 'ef', 'gh', '']
