# %%
ad = "edip"
print(type(ad))
# Out:
# <class 'str'>

# %%
import keyword
print(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
x = y = z = 'same'
print(x*3)
# Out:
# samesamesame

# %%
print("ahmet"*3, end="?")
# Out:
# ahmetahmetahmet?

# %%
volter = None
stringA = ""
intA = 0

# %%
a, b, c = 4, 3.5, "ufuk"
print(a, b, c)
print(4**4)
# Out:
# 4 3.5 ufuk
# 256

# %%
PI = 4.5
r = 5
area = 2*PI*r**2
print("area...:", area)
# Out:
# area...: 225.0

# %%
my_text = """ sei eine gute Person"""
print(type(my_text))
no = 54
print(type(no))
no2 = 3.55
print(type(no2))
no3 = 3.45j
print(type(no3))
# Out:
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'complex'>

# %%
mail = "edipnegiz@gmail.com"
no = 632
text1 = "Es ist bereit"
print(type(mail), type(str(no)), type(text1))
# Out:
# <class 'str'> <class 'str'> <class 'str'>

# %%
sayi = 3.5
sayi2 = -1*int(sayi)*2**10000
print(type(sayi), type(sayi2))
# Out:
# <class 'float'> <class 'int'>

# %%
no1 = 35
no2 = 40
print(no1 + no2)
print(str(no1) + str(no2))
# Out:
# 75
# 3540

# %%
print(int("5" + "1"))
# Out:
# 51

# %%
print(int(5 + 3))
print(5 + float("5" + "3"))
print(int(True) + bool("ahmet"))
# Out:
# 8
# 58.0
# 2

# %%
print(bool(0))
print(bool(5))
print(bool(None))
print(bool(3) + bool(4))
# Out:
# False
# True
# False
# 2

# %%
print(bool(2))
print(bool("")) # None
print(bool("")) # None
print(bool(0))
# Out:
# True
# False
# False
# False

# %%
from typing_extensions import Final
r = 5
pi: Final = 3.14 # gercek bir sabit icin Final yazilir
# area = pi * r**2
# area = pi * pow(r,2) # ust almak icin pow kullanilabilir
print(area)
# Out:
# 78.5

# %%
print(11 % 2) # mod alma islemidir ve bölümde kalani verir
a = (1 + 3) ** (2 ** ( 1 * 2 / 2) / 2) # parantez ici her zaman once yapilir
print(int(a))
# Out:
# 1
# 4

# %%
import math
#print(dir(math))
a = 3
b = 4
# c = math.sqrt(a ** 2 + b ** 2) # kök alma yöntemi
c = (a ** 2 + b ** 2) ** 0.5 # kök alma diger yol
print(c)
# Out:
# 5.0

# %%
text1 = 'I bought'
text2 = 'kg elma satin aldim'
amount = 6
print(text1, amount, text2, end=' ') # burada "end" oldugu icin asagiya gecmiyor
print('ve eve geldim')
print('I bought', 6, 'kg elma satin aldim', sep='*') # sep komutu burada araya ekleme yapar
print(text1, amount, text2, sep='')
# Out:
# I bought 6 kg elma satin aldim ve eve geldim
# I bought*6*kg elma satin aldim
# I bought6kg elma satin aldim

# %%
x = 5
print('X degeri: ', x)
x += 2
print(x, '\n')
y = 10
y -= 2
print(y, '\n')
z = 6
z *= 2
print(z)
# Out:
# X degeri:  5
# 7
#
# 8
#
# 12

# %%
print('C:\\north pole\noise_penguins.txt')
# burada zaten tirnak icinde oldugu icin direk \n direk asagi atti
# cift slas "\\" yaparsak sadece bir slas yazar
print('it\'s essential') # tirnak slas "\" ile kullanildigi icin ayni olmasi fark etmez
# Out:
# C:\north pole
# oise_penguins.txt
# it's essential

# %%
text = "Clarusway, "

print(text * 3, '\n\t', text * 3, '\n\t\t', text * 3)
# Out:
# Clarusway, Clarusway, Clarusway,
# 	 Clarusway, Clarusway, Clarusway,
# 		 Clarusway, Clarusway, Clarusway,

# %%
bool_var = False and not True
print(bool_var)
# islem sirasi soyle : not > and > or
# Out:
# False

# %%
print(3 and 'ahmet') # false arar bulursa ilk false degeri yazar
# '', "", {} bu degerler false
# and carpma islemi gibidir, or toplama islemi gibidir
print(2 or 'I am gut')
print(3 and 'ali' and 5) # en son true degeri yazar
print(4 or 'ufuk' or '') # true ariyor ilk buldugu true degeri yazar
print(0 or '' or None) # sona kadar true arar yoksa son False yazar
print(True and False or False or not True)
# Out:
# ahmet
# 2
# 5
# 4
# None
# False

# %%
# bir sayinin tek mi cift mi oldugunu bulan program
# a = 6
b = input('bir sayi gir: ')
#if a % 2 == 0:
#  print('cift')
#else:
#  print('tek')
# if kullanmadan yapimi
print(int(b) % 2 and 'tek' or 'cift')
#       0 and 'tek' or 'cift'
#       0 or 'cift'
#       'cift'
# Out:
# bir sayi gir: 3
# tek

# %%
a = 5
b = '5'
print(a is int(b)) 
print(a == b) 
print(id(a), id(b)) # adreslere bakar adres ayni ise true verir
# Out:
# True
# False
# 94450429282944 140373367749424

# %%
a = 500
b = a
c = 500
print(a is b) # bellek adresleri ayni mi diye bakar
print(a is c)
print(a != c) # esit degil mi anlamindadir
print(a == c) # degerleri asit mi diye bakar
print(id(a), id(b), id(c))
# Out:
# True
# False
# False
# True
# 140372844989424 140372844989424 140372844988720

# %%
a = 3
b = 5
print(a < b and b == 5 or not b) # karsilastirma degerleri hep true, false verir
# Out:
# True

# %%
a = int(input('Bir sayi girin: '))
print(3<a<6 and 'tr' or 'fl') # tirnak icindeki ifadeyi yazar
print('1' or '0') # tirnak icine yazilan hersey true olur
print(1 or 0)
# Out:
# Bir sayi girin: 3
# fl
# 1
# 1
