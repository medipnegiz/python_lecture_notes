# %%
a = 'süleymaniye'
print(a[:2] + 'i' + a[2:])          # karakter degistirmek icin kullanilir
a = a.replace('m','a')
print(a)
# Out:
# süileymaniye
# süleyaaniye

# %%
date = 1453
city = 'Istanbul'
land = 'Turkey'
print('Tarih:', date)
print('Tarih: ' + str(date))
print('Tarih: {}'.format(date))
print(f'Tarih: {date}')
print('Tarih: %s' %(date))                                        # eski bir yöntem bunun yerine .format kullanilabilir
print('{} tarihinde {} fethedildi'.format(date, city))            # atamayi aralara yapiyor
print('{1} tarihinde {0} fethedildi'.format(date, city, land))    # numara ile iceriden secme olabilir
print(f'{date} tarihinde {city} fethedildi')                      # sadece f kullanilarak ayni islem yapilir
# Out:
# Tarih: 1453
# Tarih: 1453
# Tarih: 1453
# Tarih: 1453
# Tarih: 1453
# 1453 tarihinde Istanbul fethedildi
# Istanbul tarihinde 1453 fethedildi
# 1453 tarihinde Istanbul fethedildi
# 1453 tarihinde Istanbul fethedildi

# %%
meyve, sebze, kilo, tutar = 'Elma', 'Domates', 2, 10
print(meyve)
# Out:
# Elma

# %%
s = f'{2 ** 3}'                       # uclu parantez icinde olunca islem olarak görüyor
s2 = '{2 ** 3}'
s3 = f'2 ** 3 = {2 ** 3}'             # uclu parantez yoksa aynisini yazar
s4 = '2 ** 3 = {}'.format(2**3)
print(s)
print(s2)
print(s3)
print(s4)
# Out:
# 8
# {2 ** 3}
# 2 ** 3 = 8
# 2 ** 3 = 8

# %%
name ='Ufuk gökkaya'
print(name.capitalize())    # sadece ilk kelime ilk harfi büyük
print(name.title())         # bütün kelimelerin ilk harfi büyük
print(len(name))
print(name.count('a'))      # icinde kac tane har oldugunu verir "büyük kücük harf duyarli"
print(name.count(''))
# Out:
# Ufuk gökkaya
# Ufuk Gökkaya
# 12
# 2
# 13

# %%
metin = 'bütün kelimelerin ilk harfi büyük'
w = metin.count(' ')
h = len(metin) - w
print('harf sayisi: ', len(metin))
print('kelime sayisi: ', metin.count(' ') + 1)      #   kelime sayisini verir ama bir eksik verir
print('harf sayisi:', h)                            #   bosluklar haric harf sayisini verir
print('Kelime sayisi:', w + 1)
# Out:
# harf sayisi:  33
# kelime sayisi:  5
# harf sayisi: 29
# Kelime sayisi: 5

# %%
name = 'Ufuk'
job = 'teacher'
domain = 'AWS / DevOps'
message = f'Hi {name}'\
    f'You are the job {job}'\
    f'in the {domain}'            # alt satira gecmek icin \ kullanilir
print(message)
# Out:
# Hi UfukYou are the job teacherin the AWS / DevOps

# %%
n = 'Susan'
a = ' young'
g = 'lady'
s = 'Clarusway'
print(f'{n} is a {a} {g} and she is a student in {s}')
out = (
    f'{n} is a {a} '
    f'{g} and she is a student '
    f'in {s}'
)
print('{} is a {} {} and she is a student in {}'.format(n, a, g, s))
print(out)
# Out:
# Susan is a  young lady and she is a student in Clarusway
# Susan is a  young lady and she is a student in Clarusway
# Susan is a  young lady and she is a student in Clarusway

# %%
st = 'Murat '
st2 = 3 * st
print(st * 3)
print(st2)
print(*st)        #  kelimeler arasina * bosluk ekler
# Out:
# MuratMuratMurat
# MuratMuratMurat
# M u r a t

# %%
str_one = 'Muhammed Cosgun'
str_two = list(str_one)       #   degistirme yapmak icin list icine almak gerekir
str_two[2] = 'r'              #   icindeki karakterden degistirme yaptirdik
print(*str_two)
print(*str_one)               #   basina konan * isareti bosluklu yazdirir
# Out:
# M u r a m m e d   C o s g u n
# M u h a m m e d   C o s g u n

# %%
okul = 'Clarusway'
print(okul.startswith('C'))             #   degerin ne ile basladigini sorariz True / False verir
print(okul.endswith('a'))               #   degerin ne ile bittigini True / False olarak verir
print(okul.find('a'))                   #   icindeki "a" nin konumunu verir
print(okul.find('a', 3, len(okul)))     #   icindeki "a" nin konumunu verir ama 3 ten baslar
print(okul.index('C'))                  #   buda konumunu söyler
# Out:
# True
# False
# 2
# 7
# 0

# %%
# yazinin boyutlarini degistirdik buyuk kucuk
yazi = 'Clarusway university'
print(yazi.swapcase()) 
print(yazi.upper())
print(yazi.lower())
print(yazi.capitalize())
print(yazi.title())
# Out:
# cLARUSWAY UNIVERSITY
# CLARUSWAY UNIVERSITY
# clarusway university
# Clarusway university
# Clarusway University

# %%
email = 'mahmutedipnegiz@gmail.com'
print(email.startswith('e', 6))     # verilen sayi baslangic olarak aliyor
print(email.endswith('@', 0, 16))   # bu aralik hangi karakter ile bitiyor ile soruyoruz (16 son bitis yerini verir dahil olmaz)
# Out:
# True
# True

# %%
text ='Clarusway'
n = 3
n_text = text[:n] + text[n+1:]
print(n_text)
# Out:
# Clausway

# %%
# %d : int
# %s : string
# %f : float
# %a : ASCI
yazi = '%d kilo %s ve %s satin aldim' % (3, 'elma', 'portakal')
print(yazi)

yazi_2 = '{} kilo {} ve {} satin alamadim'.format(3, 'elma','portakal' )
print(yazi_2)

yazi_3 = f'{3} kilo {"armut"} ve {"muz"} alacagim'
print(yazi_3)
# Out:
# 3 kilo elma ve portakal satin aldim
# 3 kilo elma ve portakal satin alamadim
# 3 kilo armut ve muz alacagim

# %%
num = 3.1456789
num2 = 1234679890
print('Pi sayisi : {:06.2f}'.format(num))      #   float otomatik yukari yuvarlar 
print(f'PI sayisi {num:.4f}')
print(f'{num2:,}')  	                         #   verilen sayiyi parasal deger cinsinden gösteriyor
# Out:
# Pi sayisi : 003.15
# PI sayisi 3.1457
# 1,234,679,890

# %%
var = ' In the God'
var.lower()     
print(var)
var.upper()       # print icine almadan direk bununla da cikti alinabilir
# Out:
#  In the God
# ' IN THE GOD'

# %%
mail = 'edipnegizgmail.com'
print('@' in mail)                          #   icinde istedigimiz harf var mi diye bakar (True ve False verir)
print('r' not in mail)                      #   icinde yok mu diye bakar (True ve False verir)
print('@' in mail and '.' in mail)          #   mailin dogru girildigini kontrol eder
# Out:
# False
# True
# False

# %%
mail = input('Mailinizi girin: ')     #   mail yanlis ise mesaj verdik
if '@' in mail and '.' in mail:
  print('mailiniz dogru')
else:
  print('yanlis girdiniz')
# Out:
# Mailinizi girin: edipnegiz@gmail.com
# mailiniz dogru

# %%
mail = 'www.edipnegizgmail.com'
print(mail.endswith('.co'))
print(mail.startswith('w'))
mail_2 = 'eskisehir universitesi bilgisayar bolumu'
print(mail_2.endswith(('hir', 'si', 'mu')))           #   herhangi biri ile bitiyorsa True verir
# Out:
# False
# True
# True

# %%
yazi = 'Galatasaray'
sayi = '44455566'
yazi = yazi.replace('a', 'e', 2)      #   sonda verilen deger kadar degisirme yapar
sayi = sayi.replace('4', '5')         #   normal sayida degistirme yapmaz bu "string" metodu
print(yazi)
print(sayi)
# Out:
# Geletasaray
# 55555566

# %%
text = 'cimbombom'
#text = text[::-1]
text = ''.join(reversed(text))        #   ters cevirme islemi icin kullanilir (reversed)
text_2 = ' # '.join(text)             #   " join " her karakter sonrasina ekleme yapar. tirnak icindekini parantez icindeki karakterlerin arasina dagitir.
print(text)
print(text_2)
# Out:
# mobmobmic
# m # o # b # m # o # b # m # i # c

# %%
text = 'interprobesn-way'
text = text.strip('iy')         #   sagdan ve soldan belirtilen harfleri kaldirir
text_2 = text.lstrip('in')      #   soldan istedigimiz karakteri kaldirir. hangisini bulursa onu kaldirir
text_3 = text.rstrip('iy')      #   sagdan girilen karakterleri kaldirir. hangisini bulursa onu kaldirir
print(text)
print(text_2)
print(text_3)
# Out:
# nterprobesn-wa
# terprobesn-wa
# nterprobesn-wa

# %%
yaz = 'Okul sonu'
yaz_2 = yaz.center(15, '+')     #    sola ve saga ekleme yapar istenilen karakter sayisi dolana kadar
yaz_3 = yaz.ljust(20, '.')      #    yaziyi sola yasla ve solunu istenilen sayi kadar karakter ile doldur
yaz_4 = yaz.rjust(25, '=')      #    saga yaslar ve sola istenilen sayi kadar karakter ekler
numb = '12346789'
print(yaz.zfill(15))           #   yazinin sol tarafina istenilen kadar " 0 " ile doldurur
print(yaz_2)
print(yaz_3)
print(yaz_4)
# Out:
# 000000Okul sonu
# +++Okul sonu+++
# Okul sonu...........
# ================Okul sonu

# %%
text = 'tclarusway university classz'
sep = text[0] + text[-1]                            #   son ve ilk karakteri sectik ve asagida onlari kaldirdik
text3 = text.strip(sep).upper()
text2 = text.strip('tz').upper()                    #   soldan ve sagdan secilen karakteri sildi ve hepsini büyük yapti
text4 = text.lstrip('t').rstrip('z').upper()        #   soldan ve sagdan kaldirma yapar
print(text2)
print(text3)
print(text4)
# Out:
# CLARUSWAY UNIVERSITY CLASS
# CLARUSWAY UNIVERSITY CLASS
# CLARUSWAY UNIVERSITY CLASS

# %%
text = 'In God wee Trust'
sil = text[9]
text4 = text[:9] + text[10:]
text2 = text.strip(text[8])
text3 = text.replace('ee' , 'e')                  #   fazla yazilan kaldirmak icin kullandik
print(text2)
print(text3)
print(text4)
print(text.replace(text[8:10], 'e'))
# Out:
# In God wee Trust
# In God we Trust
# In God we Trust
# In God we Trust

# %%
text = 'In God wee Trust'
indis = text.find('e')            #   soldan saga dogru verilen karakteri arar ve onun indeksini verir
indis2 = text.rfind('e')          #   sagdan sola dogru verilen karakteri arar ve onun indeksini verir
text2 = text.lstrip(text[indis])
print(text2)
print(indis)
print(indis2)
# Out:
# In God wee Trust
# 8
# 9

# %%
from keyword import iskeyword
print(iskeyword('Hello'))
print(iskeyword('def'))
# Out:
# False
# True

# %%
import sys
srm = sys.version.split()
print(srm)
print('Python sürümünüz..: ', srm[0])
# Out:
# ['3.7.12', '(default,', 'Jan', '15', '2022,', '18:48:18)', '[GCC', '7.5.0]']
# Python sürümünüz..:  3.7.12

# %%
text = 'Clarusway + kursu + önemli'
text2 = text.split(' +')                #   ayristirma islemi yapiyor. icine girilen karakteri kaldiriyor ve virgül ile yaziyor.
print(*text)                            #   " * " koyarak ayri yazmasini sagladik
print(text2)
# Out:
# C l a r u s w a y   +   k u r s u   +   ö n e m l i
# ['Clarusway', ' kursu', ' önemli']

# %%
text = 'ali, veli, hans, murat'
dizi = text.split(',')          #   neye göre ayiracagini secebiliyoruz (iceri girilen karaktere bakiyor)
print(dizi)
print(dizi[2])                  #   ayirma icinde secileni yazdirir
# Out:
# ['ali', ' veli', ' hans', ' murat']
#  hans

# %%
gir = 'ali'
print(gir == 'ali')           #   " == " ile kiyaslama yapabiliriz
# Out:
# True
